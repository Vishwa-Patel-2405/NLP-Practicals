# %%
from gnewsclient import gnewsclient

# %%
client = gnewsclient.NewsClient()

# %%
client.get_news()
# Out:
# [{'title': 'Florida Rep. Wasserman Schultz nearly struck in Pride parade crash that kills at least 1: reports - Fox News',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiemh0dHBzOi8vd3d3LmZveG5ld3MuY29tL3VzL2Zsb3JpZGEtcmVwLXdhc3Nlcm1hbi1zY2h1bHR6LW5lYXJseS1zdHJ1Y2staW4tcHJpZGUtcGFyYWRlLWNyYXNoLXRoYXQta2lsbHMtYXQtbGVhc3QtMS1yZXBvcnRz0gF-aHR0cHM6Ly93d3cuZm94bmV3cy5jb20vdXMvZmxvcmlkYS1yZXAtd2Fzc2VybWFuLXNjaHVsdHotbmVhcmx5LXN0cnVjay1pbi1wcmlkZS1wYXJhZGUtY3Jhc2gtdGhhdC1raWxscy1hdC1sZWFzdC0xLXJlcG9ydHMuYW1w?oc=5',
#   'media': None},
#  {'title': "Hardline judge wins Iran's presidency amid widespread voter apathy - New York Post",
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': 'MyPillow CEO Mike Lindell said he lost $7 million on COVID-19 masks - Business Insider',
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': 'As Brazil Tops 500000 COVID-19 Deaths, Protesters Blame President - NPR',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMia2h0dHBzOi8vd3d3Lm5wci5vcmcvMjAyMS8wNi8xOS8xMDA4NDM0Nzk5L2FzLWJyYXppbC10b3BzLTUwMC0wMDAtY292aWQtMTktZGVhdGhzLXByb3Rlc3RlcnMtYmxhbWUtcHJlc2lkZW500gEA?oc=5',
#   'media': None},
#  {'title': "QAnon Believers Suggest Secret Message Behind Announcement of Biden Dog Champ's Death - Newsweek",
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': "UPDATE: 1 Dead, 5 Wounded in Saturday Evening Shooting at Oakland's Lake Merritt - CBS San Francisco",
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMiUWh0dHBzOi8vc2FuZnJhbmNpc2NvLmNic2xvY2FsLmNvbS8yMDIxLzA2LzE5L3Nob290aW5nLW9ha2xhbmQtbGFrZS1tZXJyaXR0LWZhdGFsL9IBAA?oc=5',
#   'media': None},
#  {'title': 'Boulder plans assault weapons ban after Colorado allows local gun laws - Business Insider',
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': 'How Americans Are Celebrating Juneteenth This Year - NPR',
#   'link': 'https://news.google.com/__i/rss/rd/articles/CBMic2h0dHBzOi8vd3d3Lm5wci5vcmcvMjAyMS8wNi8xOS8xMDA4MzY4ODk5L3Bob3Rvcy1hbWVyaWNhbnMtY2VsZWJyYXRlLWp1bmV0ZWVudGgtYWZ0ZXItaXQtYmVjb21lcy1hLW5hdGlvbmFsLWhvbGlkYXnSAQA?oc=5',
#   'media': None},
#  {'title': "Tropical system brings soggy conditions, flood threat across Upstate for Father's Day - WYFF4 Greenville",
#   'link': 'https://news.google.com/__?oc=5',
#   'media': None},
#  {'title': 'Chicago, Kalamazoo, Battle Creek in mid-level severe storm, isolated tornado, large hail threat for Father’s - MLive.com',
#   'link': 'https://news.google.com/__...?oc=5',
#   'media': None}]

# %%
from gnewsclient import gnewsclient

# %%
import json
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 
                     
def NewsFetch(lang, location, topic):
    client = gnewsclient.NewsClient(language = lang, location = location, topic = topic,max_results = 10)
    
    stop_words = set(stopwords.words("{}".format(lang)))
    ps = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    
    news_lst = client.get_news()
    lst =[]
    
    for i in news_lst:
        print("\n\nTitle : ",i['title'])
        print("Link : ",i['link'],end="")
        dict2 = i
        dict2.pop("media")
        lst.append(dict2)
    

    print("\n\n\nTOKENS :")
    for j in lst:
        statement = j['title']
        tokens = word_tokenize(statement)
        print("\nLENGTH OF TOKENS : ",len(tokens),end="\n")
        print("\n",tokens,end="\n\n")
        lower_str = statement.lower()
        print("LOWER STRING : \n",lower_str)
        filtered_sentence = [s for s in tokens if not s in stop_words]
        print("\nSTOP WORD REMOVAL : \n",filtered_sentence,end="\n")
        
        print("\nSTEMMER : ")
        for word in tokens:
            print(ps.stem(word),end=" ")
        
        
        lematizer_lst = nltk.pos_tag(tokens)
        print("\n\n POS : \n",lematizer_lst)
        
        POS_lst= ['VBN','VBP','VBZ','NNP','NN','CC','CD','DT','EX','FW','IN','JJ','JJR','JJS','LS','MD','NN','NNS','NNPS','PDT','POS','PRP','PRP$','RB','RBR','RBS','RP','TO','UH','VB','VBD','VBG','WDT','WP','WP$','WRB']
        print("\n LAMETTIZATION : ")
        for item in lematizer_lst:
            if item[1] in POS_lst:
                print(lemmatizer.lemmatize(item[0]),end = " ")
            else:
                pass
        
    
    json_data = json.dumps(lst)
    
    with open("GoogleNewsScrapper.json","w+") as OP:
        OP.write(json_data)

        
lang = input("Enter language :")
location = input("Enter country location : ")
topic = input("Enter news topic : ")

NewsFetch(lang,location,topic)
# Out:
# Enter language :english
# Enter country location : india
# Enter news topic : covid
#
#
# Title :  Who is Ebrahim Raisi, Iran's next president? - Al Jazeera English
# Link :  https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9SFFLVnduQkJ3M03SAQA?oc=5
#
# Title :  World Refugee Day 2021: History, Theme and Facts About Asylum Seekers - News18
# Link :  https://news.google.com/__?oc=5
#
# Title :  Google Doodle Pops Up To Wish "Happy Father's Day" - NDTV
# Link :  https://news.google.com/__i/rss/rd/articles/CBMiV2h0dHBzOi8vd3d3Lm5kdHYuY29tL3dvcmxkLW5ld3MvZ29vZ2xlLWRvb2RsZS1wb3BzLXVwLXRvLXdpc2gtaGFwcHktZmF0aGVycy1kYXktMjQ2Nzk1ONIBAA?oc=5
#
# Title :  None can change neighbours…can coexist, in interest of all: Taliban to India on shifting sands - The Indian Express
# Link :  https://news.google.com/__i/rss/rd/articles/CBMijQFodHRwczovL2luZGlhbmV4cHJlc3MuY29tL2FydGljbGUvaW5kaWEvbm9uZS1jYW4tY2hhbmdlLW5laWdoYm91cnMtY2FuLWNvZXhpc3QtaW4taW50ZXJlc3Qtb2YtYWxsLXRhbGliYW4tdG8taW5kaWEtb24tc2hpZnRpbmctc2FuZHMtNzM2Njg1Ni_SAQA?oc=5
#
# Title :  Explained: As G7 plans Build Back Better World, heres how much China has spent on Belt And Road Initiative - Firstpost
# Link :  https://news.google.com/__...?oc=5
#
# Title :  Pfizer, Moderna COVID-19 Vaccines Do Not Lower Sperm Count: Study - NDTV
# Link :  https://news.google.com/__i/rss/rd/articles/CBMidWh0dHBzOi8vd3d3Lm5kdHYuY29tL3NjaWVuY2UvY29yb25hdmlydXMtcGZpemVyLW1vZGVybmEtY292aWQtMTktdmFjY2luZXMtZG8tbm90LWxvd2VyLXNwZXJtLWNvdW50LXNheXMtc3R1ZHktMjQ2NjkzMNIBAA?oc=5
#
# Title :  Govt questions reports on rise in Indians’ Swiss bank black stash - Times of India
# Link :  https://news.google.com/__...?oc=5
#
# Title :  Brazil Passes Half A Million Covid Deaths, Experts Warn Of Worse Ahead - NDTV
# Link :  https://news.google.com/__i/rss/rd/articles/CBMibWh0dHBzOi8vd3d3Lm5kdHYuY29tL3dvcmxkLW5ld3MvYnJhemlsLXBhc3Nlcy1oYWxmLWEtbWlsbGlvbi1jb3ZpZC1kZWF0aHMtZXhwZXJ0cy13YXJuLW9mLXdvcnNlLWFoZWFkLTI0NjgwMDPSAQA?oc=5
#
# Title :  Third wave of Covid-19 arrives in UK, says expert as Delta variant wreaks havoc - Hindustan Times
# Link :  https://news.google.com/__i/rss/rd/articles/CBMijQFodHRwczovL3d3dy5oaW5kdXN0YW50aW1lcy5jb20vd29ybGQtbmV3cy90aGlyZC13YXZlLW9mLWNvdmlkLTE5LWFycml2ZXMtaW4tdWstc2F5cy1leHBlcnQtYXMtZGVsdGEtdmFyaWFudC13cmVha3MtaGF2b2MtMTAxNjI0MTA1NTk1NTE5Lmh0bWzSAQA?oc=5
#
# Title :  China unhappy with Nepal over disclosure of Sinopharm COVID vaccine price - Mint
# Link :  https://news.google.com/__i/rss/rd/articles/CBMigQFodHRwczovL3d3dy5saXZlbWludC5jb20vbmV3cy93b3JsZC9jaGluYS11bmhhcHB5LXdpdGgtbmVwYWwtb3Zlci1kaXNjbG9zdXJlLW9mLXNpbm9waGFybS1jb3ZpZC12YWNjaW5lLXByaWNlLTExNjI0MTQ2NTAxNzI0Lmh0bWzSAQA?oc=5
#
#
# TOKENS :
#
# LENGTH OF TOKENS :  14
#
#  ['Who', 'is', 'Ebrahim', 'Raisi', ',', 'Iran', "'s", 'next', 'president', '?', '-', 'Al', 'Jazeera', 'English']
#
# LOWER STRING :
#  who is ebrahim raisi, iran's next president? - al jazeera english
#
# STOP WORD REMOVAL :
#  ['Who', 'Ebrahim', 'Raisi', ',', 'Iran', "'s", 'next', 'president', '?', '-', 'Al', 'Jazeera', 'English']
#
# STEMMER :
# who is ebrahim raisi , iran 's next presid ? - al jazeera english
#
#  POS :
#  [('Who', 'WP'), ('is', 'VBZ'), ('Ebrahim', 'NNP'), ('Raisi', 'NNP'), (',', ','), ('Iran', 'NNP'), ("'s", 'POS'), ('next', 'JJ'), ('president', 'NN'), ('?', '.'), ('-', ':'), ('Al', 'NNP'), ('Jazeera', 'NNP'), ('English', 'NNP')]
#
#  LAMETTIZATION :
# Who is Ebrahim Raisi Iran 's next president Al Jazeera English
# LENGTH OF TOKENS :  15
#
#  ['World', 'Refugee', 'Day', '2021', ':', 'History', ',', 'Theme', 'and', 'Facts', 'About', 'Asylum', 'Seekers', '-', 'News18']
#
# LOWER STRING :
#  world refugee day 2021: history, theme and facts about asylum seekers - news18
#
# STOP WORD REMOVAL :
#  ['World', 'Refugee', 'Day', '2021', ':', 'History', ',', 'Theme', 'Facts', 'About', 'Asylum', 'Seekers', '-', 'News18']
#
# STEMMER :
# world refuge day 2021 : histori , theme and fact about asylum seeker - news18
#
#  POS :
#  [('World', 'NNP'), ('Refugee', 'NNP'), ('Day', 'NNP'), ('2021', 'CD'), (':', ':'), ('History', 'NN'), (',', ','), ('Theme', 'NNP'), ('and', 'CC'), ('Facts', 'NNS'), ('About', 'IN'), ('Asylum', 'NNP'), ('Seekers', 'NNP'), ('-', ':'), ('News18', 'NN')]
#
#  LAMETTIZATION :
# World Refugee Day 2021 History Theme and Facts About Asylum Seekers News18
# LENGTH OF TOKENS :  14
#
#  ['Google', 'Doodle', 'Pops', 'Up', 'To', 'Wish', '``', 'Happy', 'Father', "'s", 'Day', "''", '-', 'NDTV']
#
# LOWER STRING :
#  google doodle pops up to wish "happy father's day" - ndtv
#
# STOP WORD REMOVAL :
#  ['Google', 'Doodle', 'Pops', 'Up', 'To', 'Wish', '``', 'Happy', 'Father', "'s", 'Day', "''", '-', 'NDTV']
#
# STEMMER :
# googl doodl pop up to wish `` happi father 's day '' - ndtv
#
#  POS :
#  [('Google', 'NNP'), ('Doodle', 'NNP'), ('Pops', 'NNP'), ('Up', 'NNP'), ('To', 'TO'), ('Wish', 'VB'), ('``', '``'), ('Happy', 'JJ'), ('Father', 'NNP'), ("'s", 'POS'), ('Day', 'NNP'), ("''", "''"), ('-', ':'), ('NDTV', 'NN')]
#
#  LAMETTIZATION :
# Google Doodle Pops Up To Wish Happy Father 's Day NDTV
# LENGTH OF TOKENS :  21
#
#  ['None', 'can', 'change', 'neighbours…can', 'coexist', ',', 'in', 'interest', 'of', 'all', ':', 'Taliban', 'to', 'India', 'on', 'shifting', 'sands', '-', 'The', 'Indian', 'Express']
#
# LOWER STRING :
#  none can change neighbours…can coexist, in interest of all: taliban to india on shifting sands - the indian express
#
# STOP WORD REMOVAL :
#  ['None', 'change', 'neighbours…can', 'coexist', ',', 'interest', ':', 'Taliban', 'India', 'shifting', 'sands', '-', 'The', 'Indian', 'Express']
#
# STEMMER :
# none can chang neighbours…can coexist , in interest of all : taliban to india on shift sand - the indian express
#
#  POS :
#  [('None', 'NN'), ('can', 'MD'), ('change', 'VB'), ('neighbours…can', 'JJ'), ('coexist', 'NN'), (',', ','), ('in', 'IN'), ('interest', 'NN'), ('of', 'IN'), ('all', 'DT'), (':', ':'), ('Taliban', 'NN'), ('to', 'TO'), ('India', 'NNP'), ('on', 'IN'), ('shifting', 'VBG'), ('sands', 'NNS'), ('-', ':'), ('The', 'DT'), ('Indian', 'NNP'), ('Express', 'NNP')]
#
#  LAMETTIZATION :
# None can change neighbours…can coexist in interest of all Taliban to India on shifting sand The Indian Express
# LENGTH OF TOKENS :  23
#
#  ['Explained', ':', 'As', 'G7', 'plans', 'Build', 'Back', 'Better', 'World', ',', 'heres', 'how', 'much', 'China', 'has', 'spent', 'on', 'Belt', 'And', 'Road', 'Initiative', '-', 'Firstpost']
#
# LOWER STRING :
#  explained: as g7 plans build back better world, heres how much china has spent on belt and road initiative - firstpost
#
# STOP WORD REMOVAL :
#  ['Explained', ':', 'As', 'G7', 'plans', 'Build', 'Back', 'Better', 'World', ',', 'heres', 'much', 'China', 'spent', 'Belt', 'And', 'Road', 'Initiative', '-', 'Firstpost']
#
# STEMMER :
# explain : as g7 plan build back better world , here how much china ha spent on belt and road initi - firstpost
#
#  POS :
#  [('Explained', 'VBN'), (':', ':'), ('As', 'IN'), ('G7', 'NNP'), ('plans', 'VBZ'), ('Build', 'NNP'), ('Back', 'NNP'), ('Better', 'NNP'), ('World', 'NNP'), (',', ','), ('heres', 'VBZ'), ('how', 'WRB'), ('much', 'JJ'), ('China', 'NNP'), ('has', 'VBZ'), ('spent', 'VBN'), ('on', 'IN'), ('Belt', 'NNP'), ('And', 'CC'), ('Road', 'NNP'), ('Initiative', 'NNP'), ('-', ':'), ('Firstpost', 'NN')]
#
#  LAMETTIZATION :
# Explained As G7 plan Build Back Better World here how much China ha spent on Belt And Road Initiative Firstpost
# LENGTH OF TOKENS :  14
#
#  ['Pfizer', ',', 'Moderna', 'COVID-19', 'Vaccines', 'Do', 'Not', 'Lower', 'Sperm', 'Count', ':', 'Study', '-', 'NDTV']
#
# LOWER STRING :
#  pfizer, moderna covid-19 vaccines do not lower sperm count: study - ndtv
#
# STOP WORD REMOVAL :
#  ['Pfizer', ',', 'Moderna', 'COVID-19', 'Vaccines', 'Do', 'Not', 'Lower', 'Sperm', 'Count', ':', 'Study', '-', 'NDTV']
#
# STEMMER :
# pfizer , moderna covid-19 vaccin do not lower sperm count : studi - ndtv
#
#  POS :
#  [('Pfizer', 'NNP'), (',', ','), ('Moderna', 'NNP'), ('COVID-19', 'NNP'), ('Vaccines', 'NNP'), ('Do', 'NNP'), ('Not', 'RB'), ('Lower', 'NNP'), ('Sperm', 'NNP'), ('Count', 'NNP'), (':', ':'), ('Study', 'NNP'), ('-', ':'), ('NDTV', 'NN')]
#
#  LAMETTIZATION :
# Pfizer Moderna COVID-19 Vaccines Do Not Lower Sperm Count Study NDTV
# LENGTH OF TOKENS :  16
#
#  ['Govt', 'questions', 'reports', 'on', 'rise', 'in', 'Indians', '’', 'Swiss', 'bank', 'black', 'stash', '-', 'Times', 'of', 'India']
#
# LOWER STRING :
#  govt questions reports on rise in indians’ swiss bank black stash - times of india
#
# STOP WORD REMOVAL :
#  ['Govt', 'questions', 'reports', 'rise', 'Indians', '’', 'Swiss', 'bank', 'black', 'stash', '-', 'Times', 'India']
#
# STEMMER :
# govt question report on rise in indian ’ swiss bank black stash - time of india
#
#  POS :
#  [('Govt', 'NNP'), ('questions', 'NNS'), ('reports', 'NNS'), ('on', 'IN'), ('rise', 'NN'), ('in', 'IN'), ('Indians', 'NNP'), ('’', 'NNP'), ('Swiss', 'NNP'), ('bank', 'NN'), ('black', 'JJ'), ('stash', 'NN'), ('-', ':'), ('Times', 'NNS'), ('of', 'IN'), ('India', 'NNP')]
#
#  LAMETTIZATION :
# Govt question report on rise in Indians ’ Swiss bank black stash Times of India
# LENGTH OF TOKENS :  15
#
#  ['Brazil', 'Passes', 'Half', 'A', 'Million', 'Covid', 'Deaths', ',', 'Experts', 'Warn', 'Of', 'Worse', 'Ahead', '-', 'NDTV']
#
# LOWER STRING :
#  brazil passes half a million covid deaths, experts warn of worse ahead - ndtv
#
# STOP WORD REMOVAL :
#  ['Brazil', 'Passes', 'Half', 'A', 'Million', 'Covid', 'Deaths', ',', 'Experts', 'Warn', 'Of', 'Worse', 'Ahead', '-', 'NDTV']
#
# STEMMER :
# brazil pass half a million covid death , expert warn of wors ahead - ndtv
#
#  POS :
#  [('Brazil', 'NNP'), ('Passes', 'VBZ'), ('Half', 'PDT'), ('A', 'DT'), ('Million', 'NNP'), ('Covid', 'NNP'), ('Deaths', 'NNP'), (',', ','), ('Experts', 'NNP'), ('Warn', 'NNP'), ('Of', 'IN'), ('Worse', 'NNP'), ('Ahead', 'NNP'), ('-', ':'), ('NDTV', 'NN')]
#
#  LAMETTIZATION :
# Brazil Passes Half A Million Covid Deaths Experts Warn Of Worse Ahead NDTV
# LENGTH OF TOKENS :  18
#
#  ['Third', 'wave', 'of', 'Covid-19', 'arrives', 'in', 'UK', ',', 'says', 'expert', 'as', 'Delta', 'variant', 'wreaks', 'havoc', '-', 'Hindustan', 'Times']
#
# LOWER STRING :
#  third wave of covid-19 arrives in uk, says expert as delta variant wreaks havoc - hindustan times
#
# STOP WORD REMOVAL :
#  ['Third', 'wave', 'Covid-19', 'arrives', 'UK', ',', 'says', 'expert', 'Delta', 'variant', 'wreaks', 'havoc', '-', 'Hindustan', 'Times']
#
# STEMMER :
# third wave of covid-19 arriv in uk , say expert as delta variant wreak havoc - hindustan time
#
#  POS :
#  [('Third', 'JJ'), ('wave', 'NN'), ('of', 'IN'), ('Covid-19', 'NNP'), ('arrives', 'NNS'), ('in', 'IN'), ('UK', 'NNP'), (',', ','), ('says', 'VBZ'), ('expert', 'NN'), ('as', 'IN'), ('Delta', 'NNP'), ('variant', 'VBP'), ('wreaks', 'NNS'), ('havoc', 'SYM'), ('-', ':'), ('Hindustan', 'NNP'), ('Times', 'NNP')]
#
#  LAMETTIZATION :
# Third wave of Covid-19 arrives in UK say expert a Delta variant wreaks Hindustan Times
# LENGTH OF TOKENS :  13
#
#  ['China', 'unhappy', 'with', 'Nepal', 'over', 'disclosure', 'of', 'Sinopharm', 'COVID', 'vaccine', 'price', '-', 'Mint']
#
# LOWER STRING :
#  china unhappy with nepal over disclosure of sinopharm covid vaccine price - mint
#
# STOP WORD REMOVAL :
#  ['China', 'unhappy', 'Nepal', 'disclosure', 'Sinopharm', 'COVID', 'vaccine', 'price', '-', 'Mint']
#
# STEMMER :
# china unhappi with nepal over disclosur of sinopharm covid vaccin price - mint
#
#  POS :
#  [('China', 'NNP'), ('unhappy', 'JJ'), ('with', 'IN'), ('Nepal', 'NNP'), ('over', 'IN'), ('disclosure', 'NN'), ('of', 'IN'), ('Sinopharm', 'NNP'), ('COVID', 'NNP'), ('vaccine', 'NN'), ('price', 'NN'), ('-', ':'), ('Mint', 'NN')]
#
#  LAMETTIZATION :
# China unhappy with Nepal over disclosure of Sinopharm COVID vaccine price Mint

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\VISHWA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VISHWA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\VISHWA\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\VISHWA\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd

# %%
df = pd.read_json ('GoogleNewsScrapper.json')
df.to_csv ('GoogleNewsScrapper.csv')

# %%
df
# Out:
#                                                title  \
# 0  Who is Ebrahim Raisi, Iran's next president? -...
# 1  World Refugee Day 2021: History, Theme and Fac...
# 2  Google Doodle Pops Up To Wish "Happy Father's ...
# 3  None can change neighbours…can coexist, in int...
# 4  Explained: As G7 plans Build Back Better World...
# 5  Pfizer, Moderna COVID-19 Vaccines Do Not Lower...
# 6  Govt questions reports on rise in Indians’ Swi...
# 7  Brazil Passes Half A Million Covid Deaths, Exp...
# 8  Third wave of Covid-19 arrives in UK, says exp...
# 9  China unhappy with Nepal over disclosure of Si...
#
#                                                 link
# 0  https://news.google.com/__i/rss/rd/articles/CB...
# 1  https://news.google.com/__i/rss/rd/articles/CB...
# 2  https://news.google.com/__i/rss/rd/articles/CB...
# 3  https://news.google.com/__i/rss/rd/articles/CB...
# 4  https://news.google.com/__i/rss/rd/articles/CB...
# 5  https://news.google.com/__i/rss/rd/articles/CB...
# 6  https://news.google.com/__i/rss/rd/articles/CB...
# 7  https://news.google.com/__i/rss/rd/articles/CB...
# 8  https://news.google.com/__i/rss/rd/articles/CB...
# 9  https://news.google.com/__i/rss/rd/articles/CB...
